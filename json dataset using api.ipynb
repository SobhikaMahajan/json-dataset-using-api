# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=97d4d3503004eebbdeee08777c829c66&language=en-US&page=1')

# %%
temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df=pd.DataFrame()

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=97d4d3503004eebbdeee08777c829c66&language=en-US&page={}'.format(i))
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df= df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\sobhi\AppData\Local\Temp\ipykernel_11992\2771814274.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= df.append(temp_df,ignore_index=True)
# C:\Users\sobhi\AppData\Local\Temp\ipykernel_11992\2771814274.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= df.append(temp_df,ignore_index=True)
# C:\Users\sobhi\AppData\Local\Temp\ipykernel_11992\2771814274.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= df.append(temp_df,ignore_index=True)
# C:\Users\sobhi\AppData\Local\Temp\ipykernel_11992\2771814274.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= df.append(temp_df,ignore_index=True)
# ...

# %%
df
# Out:
#           id                       title  \
# 0        238               The Godfather
# 1        278    The Shawshank Redemption
# 2     772071            Cuando Sea Joven
# 3        240       The Godfather Part II
# 4        424            Schindler's List
# ...      ...                         ...
# 8555   74944          War of the Buttons
# 8556   23827         Paranormal Activity
# 8557  505707  Waiting for the Barbarians
# 8558  443319           Phoenix Forgotten
# 8559   97051            Would You Rather
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     70-year-old Malena gets a second chance at lif...   2022-09-14
# 3     In the continuing saga of the Corleone crime f...   1974-12-20
# 4     The true story of how businessman Oskar Schind...   1993-12-15
# ...

# %%
df.to_csv('movies.csv')
